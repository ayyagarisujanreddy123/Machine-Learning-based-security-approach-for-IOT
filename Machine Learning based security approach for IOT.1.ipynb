# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# # Set display options
# pd.set_option('display.max_rows', None)  
# pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv("C:\\Users\\111bh\\UNSW-NB15_c\\UNSW_NB15_training-set.csv")
data = data.drop("attack_cat",axis =1)

# %%
x=data.dtypes
x
# Out:
# id                     int64
# dur                  float64
# proto                 object
# service               object
# state                 object
# spkts                  int64
# dpkts                  int64
# sbytes                 int64
# dbytes                 int64
# rate                 float64
# sttl                   int64
# dttl                   int64
# sload                float64
# dload                float64
# sloss                  int64
# dloss                  int64
# sinpkt               float64
# dinpkt               float64
# sjit                 float64
# djit                 float64
# swin                   int64
# stcpb                  int64
# dtcpb                  int64
# dwin                   int64
# tcprtt               float64
# synack               float64
# ackdat               float64
# smean                  int64
# dmean                  int64
# trans_depth            int64
# response_body_len      int64
# ct_srv_src             int64
# ...

# %%
data
# Out:
#           id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0          1  0.000011   udp       -   INT      2      0     496       0
# 1          2  0.000008   udp       -   INT      2      0    1762       0
# 2          3  0.000005   udp       -   INT      2      0    1068       0
# 3          4  0.000006   udp       -   INT      2      0     900       0
# 4          5  0.000010   udp       -   INT      2      0    2126       0
# ...      ...       ...   ...     ...   ...    ...    ...     ...     ...
# 82327  82328  0.000005   udp       -   INT      2      0     104       0
# 82328  82329  1.106101   tcp       -   FIN     20      8   18062     354
# 82329  82330  0.000000   arp       -   INT      1      0      46       0
# 82330  82331  0.000000   arp       -   INT      1      0      46       0
# 82331  82332  0.000009   udp       -   INT      2      0     104       0
#
#                 rate  ...  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# ...

# %%
data.describe()
# Out:
#                  id           dur         spkts         dpkts        sbytes  \
# count  82332.000000  82332.000000  82332.000000  82332.000000  8.233200e+04
# mean   41166.500000      1.006756     18.666472     17.545936  7.993908e+03
# std    23767.345519      4.710444    133.916353    115.574086  1.716423e+05
# min        1.000000      0.000000      1.000000      0.000000  2.400000e+01
# 25%    20583.750000      0.000008      2.000000      0.000000  1.140000e+02
# 50%    41166.500000      0.014138      6.000000      2.000000  5.340000e+02
# 75%    61749.250000      0.719360     12.000000     10.000000  1.280000e+03
# max    82332.000000     59.999989  10646.000000  11018.000000  1.435577e+07
#
#              dbytes          rate          sttl          dttl         sload  \
# count  8.233200e+04  8.233200e+04  82332.000000  82332.000000  8.233200e+04
# mean   1.323379e+04  8.241089e+04    180.967667     95.713003  6.454902e+07
# ...

# %%
data.isnull().sum()
# Out:
# id                   0
# dur                  0
# proto                0
# service              0
# state                0
# spkts                0
# dpkts                0
# sbytes               0
# dbytes               0
# rate                 0
# sttl                 0
# dttl                 0
# sload                0
# dload                0
# sloss                0
# dloss                0
# sinpkt               0
# dinpkt               0
# sjit                 0
# djit                 0
# swin                 0
# stcpb                0
# dtcpb                0
# dwin                 0
# tcprtt               0
# synack               0
# ackdat               0
# smean                0
# dmean                0
# trans_depth          0
# response_body_len    0
# ct_srv_src           0
# ct_state_ttl         0
# ct_dst_ltm           0
# ct_src_dport_ltm     0
# ct_dst_sport_ltm     0
# ct_dst_src_ltm       0
# is_ftp_login         0
# ct_ftp_cmd           0
# ct_flw_http_mthd     0
# ...

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.model_selection import train_test_split

# %%
data
# Out:
#           id       dur proto service state  spkts  dpkts  sbytes  dbytes  \
# 0          1  0.000011   udp       -   INT      2      0     496       0
# 1          2  0.000008   udp       -   INT      2      0    1762       0
# 2          3  0.000005   udp       -   INT      2      0    1068       0
# 3          4  0.000006   udp       -   INT      2      0     900       0
# 4          5  0.000010   udp       -   INT      2      0    2126       0
# ...      ...       ...   ...     ...   ...    ...    ...     ...     ...
# 82327  82328  0.000005   udp       -   INT      2      0     104       0
# 82328  82329  1.106101   tcp       -   FIN     20      8   18062     354
# 82329  82330  0.000000   arp       -   INT      1      0      46       0
# 82330  82331  0.000000   arp       -   INT      1      0      46       0
# 82331  82332  0.000009   udp       -   INT      2      0     104       0
#
#                 rate  ...  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# ...

# %%
categorical_cols = data.select_dtypes(include = ['object']).columns
categorical_cols
# Out:
# Index(['proto', 'service', 'state'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
# categorical_cols = data.select_dtypes(include = ['object']).columns
label_encoder = LabelEncoder()
data[categorical_cols] = data[categorical_cols].apply(lambda x: label_encoder.fit_transform(x))
data
# Out:
#           id       dur  proto  service  state  spkts  dpkts  sbytes  dbytes  \
# 0          1  0.000011    117        0      4      2      0     496       0
# 1          2  0.000008    117        0      4      2      0    1762       0
# 2          3  0.000005    117        0      4      2      0    1068       0
# 3          4  0.000006    117        0      4      2      0     900       0
# 4          5  0.000010    117        0      4      2      0    2126       0
# ...      ...       ...    ...      ...    ...    ...    ...     ...     ...
# 82327  82328  0.000005    117        0      4      2      0     104       0
# 82328  82329  1.106101    111        0      3     20      8   18062     354
# 82329  82330  0.000000      6        0      4      1      0      46       0
# 82330  82331  0.000000      6        0      4      1      0      46       0
# 82331  82332  0.000009    117        0      4      2      0     104       0
#
# ...

# %%
scaler = StandardScaler()
# data.columns = data.columns.astype(str)
numerical_cols = data.select_dtypes(include=['number']).columns
data[numerical_cols]=scaler.fit_transform(data[numerical_cols])

# %%
X = data.drop(['id','label'],axis=1)
y=data['label']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=7)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=20)
x_train_pca = pca.fit_transform(X_train)
x_test_pca = pca.transform(X_test)

# %%
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.fit_transform(y_test)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM,Dense,Dropout
from tensorflow.keras.optimizers import Adam

# %%
x_train_pca = x_train_pca.reshape(x_train_pca.shape[0],x_train_pca.shape[1],1)
x_test_pca = x_test_pca.reshape(x_test_pca.shape[0],x_test_pca.shape[1],1)

# %%
model =Sequential()
model.add(LSTM(256,input_shape=(x_train_pca.shape[1],1),activation='relu',return_sequences=True))
model.add(LSTM(128,activation='relu',return_sequences=True))
model.add(LSTM(64,activation='relu',return_sequences=True))
model.add(LSTM(32,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))
optimizer = Adam(learning_rate = 0.001)
model.compile(loss = 'binary_crossentropy',optimizer = optimizer,metrics=['accuracy'])

# %%
history = model.fit(x_train_pca,y_train_encoded,epochs=20,batch_size=64,validation_split=0.2)
# Out:
# Epoch 1/20
# 824/824 [==============================] - 123s 137ms/step - loss: 0.3952 - accuracy: 0.8112 - val_loss: 0.3291 - val_accuracy: 0.8454
# Epoch 2/20
# 824/824 [==============================] - 117s 142ms/step - loss: 0.3278 - accuracy: 0.8434 - val_loss: 0.3028 - val_accuracy: 0.8533
# Epoch 3/20
# 824/824 [==============================] - 112s 136ms/step - loss: 0.4344 - accuracy: 0.8456 - val_loss: 0.2980 - val_accuracy: 0.8632
# Epoch 4/20
# 824/824 [==============================] - 120s 146ms/step - loss: 0.2815 - accuracy: 0.8631 - val_loss: 0.2783 - val_accuracy: 0.8590
# Epoch 5/20
# 824/824 [==============================] - 132s 160ms/step - loss: 0.2648 - accuracy: 0.8711 - val_loss: 0.2422 - val_accuracy: 0.8814
# Epoch 6/20
# 824/824 [==============================] - 134s 163ms/step - loss: 0.2503 - accuracy: 0.8791 - val_loss: 0.2423 - val_accuracy: 0.8854
# Epoch 7/20
# ...

# %%
a = model.evaluate(x_test_pca,y_test_encoded)
print("Accuracy:"+str(a[1] * 100))
# Out:
# 515/515 [==============================] - 17s 33ms/step - loss: 0.1914 - accuracy: 0.9070
# Accuracy:90.70261716842651

# %%
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
y_pred_prob = model.predict(x_test_pca)
y_pred = (y_pred_prob > 0.5).astype(int)
conf_matrix = confusion_matrix(y_test_encoded, y_pred)
# Out:
# 515/515 [==============================] - 16s 28ms/step

# %%
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='g', cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()

# %%
from sklearn.metrics import classification_report

classification_rep = classification_report(y_test_encoded, y_pred)
print("Classification Report:\n", classification_rep)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.97      0.90      7391
#            1       0.97      0.86      0.91      9076
#
#     accuracy                           0.91     16467
#    macro avg       0.91      0.91      0.91     16467
# weighted avg       0.92      0.91      0.91     16467

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

precision = precision_score(y_test_encoded, y_pred)
recall = recall_score(y_test_encoded, y_pred)
f1 = f1_score(y_test_encoded, y_pred)

print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Precision: 0.9706799750467873
# Recall: 0.8572058175407669
# F1 Score: 0.910420689251653

# %%
import matplotlib.pyplot as plt

metrics = ['Precision', 'Recall', 'F1 Score']
values = [precision, recall, f1]

plt.figure(figsize=(8, 6))
plt.bar(metrics, values, color=['blue', 'green', 'orange'])
plt.title('Performance Metrics')
plt.xlabel('Metrics')
plt.ylabel('Score')
plt.ylim(0, 1)  
plt.show()

# %%
import matplotlib.pyplot as plt

metrics = ['Accuracy', 'Precision', 'Recall', 'F1 Score']
values = [a[1], precision, recall, f1]

plt.figure(figsize=(8, 6))
plt.bar(metrics, values, color=['red', 'blue', 'green', 'orange'])
plt.title('Performance Metrics')
plt.xlabel('Metrics')
plt.ylabel('Score')
plt.ylim(0, 1)  
plt.show()
